# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch
import torch.nn as nn
from torchvision import transforms
from torch.autograd import Variable
import torchvision.datasets as dataset

from torch.optim import lr_scheduler
from IPython.core.debugger import set_trace
import matplotlib.pyplot as plt
from PIL import Image

import os
import numpy as np
import pandas as pd
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cf59fa9fb2f6> in <module>()
#      21 import bcolz
#      22 import time
# ---> 23 from utils import *
#
# ModuleNotFoundError: No module named 'utils'

# %%
from pdb import set_trace
import shutil

# %% [markdown]
# ### Resizing images

# %% [markdown]
# The original images were ~3000x3000. I have resized it to 300x300 for computational efficiency.

# %%
# sz = (300,300) #specify the final size

# %%
# fn1 = !ls data/normal
# fn2 = !ls data/condition

# %%
# for n in fn1:
# #     set_trace()
# #     print(n)
#     im = Image.open(f'data/normal/{n}')
#     im.thumbnail(sz,Image.ANTIALIAS)
#     im.save(f'data/montgomery_china_resized/normal/{n}',format='png')

# %%
# for n in fn2:
# #     set_trace()
# #     print(n)
#     im = Image.open(f'data/condition/{n}')
#     im.thumbnail(sz,Image.ANTIALIAS)
#     im.save(f'data/montgomery_china_resized/condition/{n}',format='png')

# %% [markdown]
# ---

# %% [markdown]
# We have 800 X-ray images. We have split it into train (680 images) and validation (120 images). 15% validation

# %% [markdown]
# ### Sample image

# %%
path = 'data/'

# %%
sample = plt.imread('data/montgomery_china_resized/train/normal/CHNCXR_0001_0.png')

# %%
sample.shape
# Out:
# (291, 300, 3)

# %%
plt.imshow(sample)

# %% [markdown]
# ---

# %% [markdown]
# ### Transforms examples

# %% [markdown]
# Below are some few kind of transforms that are generally used for data augmentation

# %%
sample = Image.open('data/montgomery_china_resized/train/normal/CHNCXR_0001_0.png')

# %%
plt.imshow(sample) #actual image

# %% [markdown]
# #### Center Crop

# %%
t = transforms.CenterCrop(200)
t(sample)

# %%
t = transforms.RandomResizedCrop(256,scale=(1,1))
t(sample)

# %% [markdown]
# #### Random Crop

# %%
t = transforms.RandomCrop(200)
t(sample)

# %%
t(sample).size

# %% [markdown]
# #### Horizontal Flip

# %%
t = transforms.RandomHorizontalFlip()
t(sample)

# %% [markdown]
# #### Vertical Flip

# %%
t = transforms.RandomVerticalFlip()

t(sample)

# %% [markdown]
# #### Rotation

# %%
t = transforms.RandomRotation(10)

# %%
t(sample)

# %% [markdown]
# ### Data structure

# %%
# !ls data/montgomery_china_resized/train/normal/ | wc -l #number of normal images in train

# %%
# !ls data/montgomery_china_resized/train/condition/ | wc -l #number of condition images in train

# %%
# !ls data/montgomery_china_resized/valid/normal/ | wc -l #number of normal images in validation

# %%
# !ls data/montgomery_china_resized/valid/condition/ | wc -l #number of condition images in validation

# %% [markdown]
# The ratio of each class is roughly the same. I have taken 85% train and 15% validation

# %% [markdown]
# ### CNN network 1: (Conv2d → maxpool(size=2,stride=2) → RELU)x4→ linear→ logsoftmax

# %% [markdown]
# Trying a network without regularization

# %%
# CNN Model (4 conv layer)
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(2),
            nn.ReLU()
            )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.ReLU())
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.ReLU())
        self.fc1 = nn.Linear(16*16*128, 2)
        self.sm = nn.LogSoftmax(dim = 1)
        
    def forward(self, x):
#         set_trace()
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.sm(out)  
        return out

# %% [markdown]
# #### Specifying the hyperparameters

# %%
cnn1 = CNN() #instantiating your CNN class
cnn1.cuda() #shifting it to gpu
criterion = nn.NLLLoss() #negative log likelihood as loss function
num_epochs = 10
lr_start = 1e-3
size = 256
batch_size = 64

# %% [markdown]
# #### Transformations and dataloader

# %% [markdown]
# For now I'm not applying any transforms apart from data pre-processing to make size consistent and normalizing the data.

# %%
# Specifying your transforms
transform = transforms.Compose([
    transforms.RandomResizedCrop(size,scale=(1,1)), #Resized images are not exactly of same size so resizing it to make the size constant
    transforms.ToTensor() #normalize the pixels by dividing it by 255
])

# %% [markdown]
# This method of data loader is used if we have 2 folders train and validation and there are separate folders for each class within them

# %%
#for training
traindir = os.path.join('data/montgomery_china_resized/', 'train')
train = dataset.ImageFolder(traindir, transform=transform)
train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True,num_workers=0)

#for validation
valdir = os.path.join('data/montgomery_china_resized/', 'valid')
valid = dataset.ImageFolder(valdir, transform=transform)
valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False,num_workers=0)

# %% [markdown]
# #### Checking dataloader

# %%
# %%time
xmb,ymb = (iter(train_loader)).next()
# Out:
# CPU times: user 428 ms, sys: 20 ms, total: 448 ms
# Wall time: 295 ms

# %%
type(xmb)
# Out:
# torch.FloatTensor

# %%
xmb.size()
# Out:
# torch.Size([64, 3, 256, 256])

# %% [markdown]
# Dataloader is outputing right size of minibatch and image size

# %% [markdown]
# ### Training and Predict functions

# %% [markdown]
# #### Saving model

# %%
def save_checkpoint(state,filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    shutil.copyfile(filename, 'model_best.pth.tar')

# %% [markdown]
# #### Train

# %%
def train(num_epochs,
          train_loader,
          valid_loader,
          cnn,
          criterion,
          batch_size,
          lr_start,
          lr_decay=False,use_checkpoint =  False,checkpoint_file = None,apply_wd = False):
    iterations = 0
    train_loss_tracker = []
    train_accuracy_tracker = []
    val_loss_tracker = []
    val_accuracy_tracker = []
    
    if apply_wd:
        optimizer = torch.optim.Adam(cnn.parameters(), lr=lr_start,weight_decay=1e-4)  #defining the optimizer
    else:
        optimizer = torch.optim.Adam(cnn.parameters(), lr=lr_start)
    if use_checkpoint:
        checkpoint = torch.load(checkpoint_file)
        cnn.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        
        
    #     scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma=0.1,last_epoch=-1)

    for epoch in range(num_epochs):
        print('Epoch [%d/%d]:' % (epoch + 1, num_epochs))
        print('-----------------')
        print("learning rate:", optimizer.param_groups[0]['lr'])
        for i, (images, labels) in enumerate(train_loader):
            #  set_trace()
            #minibatch
            images = Variable(images).cuda()  #for gpu
            labels = Variable(labels).cuda()  #for gpu

            # Forward + Backward + Optimize
            optimizer.zero_grad()  #putting all gradients to zero
            outputs = cnn(images)  #forward pass
            loss = criterion(outputs, labels)  #calculating loss
            train_loss_tracker.append(loss)
            loss.backward()  #backward pass to calculate gradients
            optimizer.step()  #updating the network parameters

            iterations += 1
            if (i + 1) % 5 == 0:
                avg_loss = np.mean(train_loss_tracker[-5:])
                print('Average loss of last 5 mini-batches: %.4f' % (avg_loss))
        print('------------')
        train_a = predict(cnn, train_loader)
        train_accuracy_tracker.append(train_a)
        print('Accuracy on training images %.4f' % (train_a))
        val_a, val_l = predict(cnn, valid_loader, False)
        if len(val_loss_tracker)>0 and val_l < min(val_loss_tracker):
            save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': cnn.state_dict(),
            'best_loss_val': val_l,
            'optimizer' : optimizer.state_dict()
        })
        val_loss_tracker.append(val_l)
        val_accuracy_tracker.append(val_a)
        print('Accuracy on test images %.4f' % (val_a))
        print('Loss on test images %.4f' % (val_l))
        print('------------')

#         scheduler.step()
#         print("learning rate:",optimizer.param_groups[0]['lr'])
    print('-----------Summary--------------')
    print('Number of iterations: %d' % (iterations))
    print('Final avg loss:%.4f' % (np.mean(train_loss_tracker[-5:])))
    val_a, val_l = predict(cnn, valid_loader, False)
    print('Accuracy on test images %.4f' % (val_a))
    print('Loss on test images %.4f' % (val_l))
    print('Minimum loss on test images during the entire training %.4f' % (min(val_loss_tracker)))
    print('Maximum accuracy on test images during the entire training %.4f' % (max(val_accuracy_tracker)))
    return train_loss_tracker,train_accuracy_tracker,val_loss_tracker,val_accuracy_tracker

# %% [markdown]
# #### Prediction

# %%
def predict(cnn, dataloader,is_train=True):
    cnn.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
    correct = 0
    total = 0
    val_loss = []
    if is_train:
        #for train
        for images, labels in dataloader:
            images = Variable(images).cuda()
            outputs = cnn(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted.cpu() == labels).sum()
        accuracy = 100 * correct / total
        return accuracy
    else:
        #for validation
        for images, labels in dataloader:
            images = Variable(images).cuda()
            labels_t = Variable(labels).cuda()
            outputs = cnn(images)
            loss = criterion(outputs, labels_t)
            val_loss.append(loss.data)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted.cpu() == labels).sum()
            images.cpu()
            labels_t.cpu()
        accuracy = 100 * correct / total
        val_loss_avg = np.mean(val_loss)
        
        return accuracy,val_loss_avg

# %% [markdown]
# #### Running the model

# %%
tl,ta,vl,va = train(10,train_loader,valid_loader,cnn1,criterion,batch_size,1e-3)
# Out:
# Epoch [1/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 5.4285
# Average loss of last 5 mini-batches: 2.7903
# ------------
# Accuracy on training images 50.8824
# Accuracy on test images 50.0000
# Loss on test images 0.8390
# ------------
# Epoch [2/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.8462
# Average loss of last 5 mini-batches: 0.7300
# ------------
# Accuracy on training images 65.4412
# Accuracy on test images 61.6667
# Loss on test images 0.6905
# ------------
# Epoch [3/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.7460
# Average loss of last 5 mini-batches: 0.6930
# ------------
# Accuracy on training images 49.1176
# Accuracy on test images 50.0000
# Loss on test images 0.7199
# ------------
# Epoch [4/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.6924
# Average loss of last 5 mini-batches: 0.6867
# ------------
# Accuracy on training images 67.7941
# Accuracy on test images 61.6667
# Loss on test images 0.6762
# ------------
# Epoch [5/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.6699
# Average loss of last 5 mini-batches: 0.6506
# ------------
# Accuracy on training images 72.5000
# Accuracy on test images 65.8333
# Loss on test images 0.6524
# ------------
# Epoch [6/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.6332
# Average loss of last 5 mini-batches: 0.5942
# ------------
# Accuracy on training images 73.6765
# Accuracy on test images 71.6667
# Loss on test images 0.6007
# ------------
# Epoch [7/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5323
# Average loss of last 5 mini-batches: 0.6002
# ------------
# Accuracy on training images 71.6176
# Accuracy on test images 66.6667
# Loss on test images 0.6238
# ------------
# Epoch [8/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5453
# Average loss of last 5 mini-batches: 0.5263
# ------------
# Accuracy on training images 75.0000
# Accuracy on test images 66.6667
# Loss on test images 0.5904
# ------------
# Epoch [9/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5730
# Average loss of last 5 mini-batches: 0.5112
# ------------
# Accuracy on training images 74.8529
# Accuracy on test images 69.1667
# Loss on test images 0.5680
# ------------
# Epoch [10/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5148
# Average loss of last 5 mini-batches: 0.5192
# ------------
# Accuracy on training images 76.1765
# Accuracy on test images 70.0000
# Loss on test images 0.5474
# ------------
# -----------Summary--------------
# Number of iterations: 110
# Final avg loss:0.5355
# Accuracy on test images 70.8333
# Loss on test images 0.5371
# Minimum loss on test images during the entire training 0.5474
# Maximum accuracy on test images during the entire training 71.6667

# %% [markdown]
# This network has been able to overfit the training data. So we have a network which can understand the training data properly. But the problem is that the network is not generalizing very well to the validation data.For that we have to try different regularization techniques.

# %% [markdown]
# ### CNN network 2: (Conv2d → maxpool(size=2,stride=2) → RELU)x4→Dropout→linear→ logsoftmax

# %%
# CNN Model (4 conv layer)
class CNN2(nn.Module):
    def __init__(self):
        super(CNN2, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(2),
            nn.ReLU()
            )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.ReLU())
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.ReLU())
        self.layer4 = nn.Sequential(
        nn.Conv2d(64, 128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.MaxPool2d(2),
        nn.ReLU(),
        nn.Dropout(p = 0.2))
        self.fc1 = nn.Linear(16*16*128, 2)
        self.sm = nn.LogSoftmax(dim = 1)
        
    def forward(self, x):
#         set_trace()
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.sm(out)  
        return out

# %% [markdown]
# #### Transformations and dataloader

# %% [markdown]
# Notice I have applied different transforms for data augmentation this time

# %%
# Specifying your transforms
transform1 = transforms.Compose([
    transforms.RandomResizedCrop(size,scale=(.9,1)), #Resized images are not exactly of same size so resizing it to make the size constant
    transforms.RandomRotation(5),
    transforms.ToTensor() #normalize the pixels by dividing it by 255
])

# %% [markdown]
# This method of data loader is used if we have 2 folders train and validation and there are separate folders for each class within them

# %%
#for training
traindir = os.path.join('data/montgomery_china_resized/', 'train')
train1 = dataset.ImageFolder(traindir, transform=transform1)
train_loader1 = torch.utils.data.DataLoader(train1, batch_size=batch_size, shuffle=True,num_workers=0)

#for validation
valdir = os.path.join('data/montgomery_china_resized/', 'valid')
valid = dataset.ImageFolder(valdir, transform=transform)
valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False,num_workers=0)

# %%
cnn2 = CNN2()
cnn2.cuda()
# Out:
# CNN2(
#   (layer1): Sequential(
#     (0): Conv2d (3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (3): ReLU()
#   )
#   (layer2): Sequential(
#     (0): Conv2d (16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (3): ReLU()
#   )
#   (layer3): Sequential(
#     (0): Conv2d (32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (3): ReLU()
#   )
#   (layer4): Sequential(
#     (0): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (3): ReLU()
#     (4): Dropout(p=0.2)
#   )
#   (fc1): Linear(in_features=32768, out_features=2)
#   (sm): LogSoftmax()
# )

# %%
tl,ta,vl,va = train(50,train_loader1,valid_loader,cnn2,criterion,batch_size,1e-3,apply_wd=True)
# Out:
# Epoch [1/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 3.2467
# Average loss of last 5 mini-batches: 1.4291
# ------------
# Accuracy on training images 50.8824
# Accuracy on test images 50.0000
# Loss on test images 0.9267
# ------------
# Epoch [2/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.8482
# Average loss of last 5 mini-batches: 0.7339
# ------------
# Accuracy on training images 50.8824
# Accuracy on test images 50.0000
# Loss on test images 0.6890
# ------------
# Epoch [3/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.7265
# Average loss of last 5 mini-batches: 0.6802
# ------------
# Accuracy on training images 73.0882
# Accuracy on test images 67.5000
# Loss on test images 0.6704
# ------------
# Epoch [4/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.6646
# Average loss of last 5 mini-batches: 0.6277
# ------------
# Accuracy on training images 74.2647
# Accuracy on test images 68.3333
# Loss on test images 0.5976
# ------------
# Epoch [5/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5313
# Average loss of last 5 mini-batches: 0.5446
# ------------
# Accuracy on training images 73.8235
# Accuracy on test images 70.0000
# Loss on test images 0.5922
# ------------
# Epoch [6/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4800
# Average loss of last 5 mini-batches: 0.5866
# ------------
# Accuracy on training images 72.0588
# Accuracy on test images 74.1667
# Loss on test images 0.5799
# ------------
# Epoch [7/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5304
# Average loss of last 5 mini-batches: 0.5329
# ------------
# Accuracy on training images 75.2941
# Accuracy on test images 73.3333
# Loss on test images 0.5333
# ------------
# Epoch [8/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5177
# Average loss of last 5 mini-batches: 0.4748
# ------------
# Accuracy on training images 78.6765
# Accuracy on test images 74.1667
# Loss on test images 0.5243
# ------------
# Epoch [9/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.5028
# Average loss of last 5 mini-batches: 0.4875
# ------------
# Accuracy on training images 71.4706
# Accuracy on test images 70.0000
# Loss on test images 0.6042
# ------------
# Epoch [10/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4941
# Average loss of last 5 mini-batches: 0.4663
# ------------
# Accuracy on training images 76.0294
# Accuracy on test images 74.1667
# Loss on test images 0.5515
# ------------
# Epoch [11/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4741
# Average loss of last 5 mini-batches: 0.4954
# ------------
# Accuracy on training images 75.2941
# Accuracy on test images 72.5000
# Loss on test images 0.5371
# ------------
# Epoch [12/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4775
# Average loss of last 5 mini-batches: 0.4493
# ------------
# Accuracy on training images 77.9412
# Accuracy on test images 72.5000
# Loss on test images 0.5047
# ------------
# Epoch [13/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4700
# Average loss of last 5 mini-batches: 0.4435
# ------------
# Accuracy on training images 79.4118
# Accuracy on test images 75.0000
# Loss on test images 0.4950
# ------------
# Epoch [14/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4643
# Average loss of last 5 mini-batches: 0.4600
# ------------
# Accuracy on training images 80.8824
# Accuracy on test images 76.6667
# Loss on test images 0.4891
# ------------
# Epoch [15/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4071
# Average loss of last 5 mini-batches: 0.5056
# ------------
# Accuracy on training images 80.7353
# Accuracy on test images 75.0000
# Loss on test images 0.4763
# ------------
# Epoch [16/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4117
# Average loss of last 5 mini-batches: 0.4694
# ------------
# Accuracy on training images 79.2647
# Accuracy on test images 76.6667
# Loss on test images 0.4819
# ------------
# Epoch [17/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4464
# Average loss of last 5 mini-batches: 0.4548
# ------------
# Accuracy on training images 81.4706
# Accuracy on test images 76.6667
# Loss on test images 0.4782
# ------------
# Epoch [18/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4545
# Average loss of last 5 mini-batches: 0.4285
# ------------
# Accuracy on training images 79.2647
# Accuracy on test images 80.8333
# Loss on test images 0.5066
# ------------
# Epoch [19/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4487
# Average loss of last 5 mini-batches: 0.4375
# ------------
# Accuracy on training images 79.4118
# Accuracy on test images 76.6667
# Loss on test images 0.5393
# ------------
# Epoch [20/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4858
# Average loss of last 5 mini-batches: 0.4263
# ------------
# Accuracy on training images 82.3529
# Accuracy on test images 80.8333
# Loss on test images 0.4657
# ------------
# Epoch [21/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4400
# Average loss of last 5 mini-batches: 0.4225
# ------------
# Accuracy on training images 83.0882
# Accuracy on test images 80.0000
# Loss on test images 0.4542
# ------------
# Epoch [22/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4339
# Average loss of last 5 mini-batches: 0.4259
# ------------
# Accuracy on training images 82.3529
# Accuracy on test images 77.5000
# Loss on test images 0.4636
# ------------
# Epoch [23/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3913
# Average loss of last 5 mini-batches: 0.4170
# ------------
# Accuracy on training images 81.4706
# Accuracy on test images 80.8333
# Loss on test images 0.4718
# ------------
# Epoch [24/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3907
# Average loss of last 5 mini-batches: 0.4890
# ------------
# Accuracy on training images 81.9118
# Accuracy on test images 80.0000
# Loss on test images 0.4712
# ------------
# Epoch [25/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4498
# Average loss of last 5 mini-batches: 0.3741
# ------------
# Accuracy on training images 81.9118
# Accuracy on test images 77.5000
# Loss on test images 0.4587
# ------------
# Epoch [26/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4226
# Average loss of last 5 mini-batches: 0.4000
# ------------
# Accuracy on training images 82.3529
# Accuracy on test images 75.8333
# Loss on test images 0.4866
# ------------
# Epoch [27/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4100
# Average loss of last 5 mini-batches: 0.3821
# ------------
# Accuracy on training images 80.7353
# Accuracy on test images 82.5000
# Loss on test images 0.4758
# ------------
# Epoch [28/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4137
# Average loss of last 5 mini-batches: 0.4442
# ------------
# Accuracy on training images 83.0882
# Accuracy on test images 80.0000
# Loss on test images 0.4460
# ------------
# Epoch [29/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4247
# Average loss of last 5 mini-batches: 0.4368
# ------------
# Accuracy on training images 81.7647
# Accuracy on test images 76.6667
# Loss on test images 0.5018
# ------------
# Epoch [30/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3983
# Average loss of last 5 mini-batches: 0.4008
# ------------
# Accuracy on training images 81.3235
# Accuracy on test images 78.3333
# Loss on test images 0.4640
# ------------
# Epoch [31/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4003
# Average loss of last 5 mini-batches: 0.3776
# ------------
# Accuracy on training images 79.7059
# Accuracy on test images 80.8333
# Loss on test images 0.4967
# ------------
# Epoch [32/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3711
# Average loss of last 5 mini-batches: 0.4484
# ------------
# Accuracy on training images 83.0882
# Accuracy on test images 78.3333
# Loss on test images 0.5043
# ------------
# Epoch [33/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4257
# Average loss of last 5 mini-batches: 0.3873
# ------------
# Accuracy on training images 79.2647
# Accuracy on test images 83.3333
# Loss on test images 0.4791
# ------------
# Epoch [34/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4099
# Average loss of last 5 mini-batches: 0.3998
# ------------
# Accuracy on training images 83.3824
# Accuracy on test images 76.6667
# Loss on test images 0.4785
# ------------
# Epoch [35/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3922
# Average loss of last 5 mini-batches: 0.4205
# ------------
# Accuracy on training images 82.0588
# Accuracy on test images 81.6667
# Loss on test images 0.4784
# ------------
# Epoch [36/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3831
# Average loss of last 5 mini-batches: 0.4479
# ------------
# Accuracy on training images 81.6176
# Accuracy on test images 76.6667
# Loss on test images 0.4755
# ------------
# Epoch [37/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4191
# Average loss of last 5 mini-batches: 0.3975
# ------------
# Accuracy on training images 83.5294
# Accuracy on test images 78.3333
# Loss on test images 0.4752
# ------------
# Epoch [38/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4168
# Average loss of last 5 mini-batches: 0.4021
# ------------
# Accuracy on training images 83.2353
# Accuracy on test images 75.8333
# Loss on test images 0.4769
# ------------
# Epoch [39/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3898
# Average loss of last 5 mini-batches: 0.4064
# ------------
# Accuracy on training images 84.5588
# Accuracy on test images 78.3333
# Loss on test images 0.4661
# ------------
# Epoch [40/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3332
# Average loss of last 5 mini-batches: 0.3849
# ------------
# Accuracy on training images 83.8235
# Accuracy on test images 79.1667
# Loss on test images 0.4506
# ------------
# Epoch [41/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4004
# Average loss of last 5 mini-batches: 0.3702
# ------------
# Accuracy on training images 85.7353
# Accuracy on test images 79.1667
# Loss on test images 0.4510
# ------------
# Epoch [42/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3854
# Average loss of last 5 mini-batches: 0.3454
# ------------
# Accuracy on training images 85.7353
# Accuracy on test images 77.5000
# Loss on test images 0.4834
# ------------
# Epoch [43/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3967
# Average loss of last 5 mini-batches: 0.3748
# ------------
# Accuracy on training images 85.4412
# Accuracy on test images 79.1667
# Loss on test images 0.4876
# ------------
# Epoch [44/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3502
# Average loss of last 5 mini-batches: 0.3771
# ------------
# Accuracy on training images 84.2647
# Accuracy on test images 80.8333
# Loss on test images 0.4793
# ------------
# Epoch [45/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3792
# Average loss of last 5 mini-batches: 0.3979
# ------------
# Accuracy on training images 83.9706
# Accuracy on test images 78.3333
# Loss on test images 0.4769
# ------------
# Epoch [46/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3733
# Average loss of last 5 mini-batches: 0.3900
# ------------
# Accuracy on training images 81.9118
# Accuracy on test images 74.1667
# Loss on test images 0.5575
# ------------
# Epoch [47/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3800
# Average loss of last 5 mini-batches: 0.3997
# ------------
# Accuracy on training images 83.6765
# Accuracy on test images 74.1667
# Loss on test images 0.4605
# ------------
# Epoch [48/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3520
# Average loss of last 5 mini-batches: 0.4102
# ------------
# Accuracy on training images 85.7353
# Accuracy on test images 79.1667
# Loss on test images 0.4805
# ------------
# Epoch [49/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4255
# Average loss of last 5 mini-batches: 0.3642
# ------------
# Accuracy on training images 83.9706
# Accuracy on test images 75.0000
# Loss on test images 0.4968
# ------------
# Epoch [50/50]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4019
# Average loss of last 5 mini-batches: 0.3432
# ------------
# Accuracy on training images 84.2647
# Accuracy on test images 79.1667
# Loss on test images 0.4586
# ------------
# -----------Summary--------------
# Number of iterations: 550
# Final avg loss:0.3365
# Accuracy on test images 80.0000
# Loss on test images 0.4556
# Minimum loss on test images during the entire training 0.4460
# Maximum accuracy on test images during the entire training 83.3333

# %%
plt.plot(vl)

# %%
plt.plot(va)

# %%
plt.plot(ta)

# %% [markdown]
# Training process is saving the best performing state of network. To load this state and continue training follow the below steps:

# %%
checkpoint = torch.load('checkpoint.pth.tar')

# %%
#loading the state in the network and predicting on the validation
cnn3 = CNN2()
cnn3.cuda()
cnn3.load_state_dict(checkpoint['state_dict'])
predict(cnn3,valid_loader,False)
# Out:
# (79.16666666666667, 0.4350486)

# %% [markdown]
# Continue training on this network using lower learning rate

# %%
cnn4 = CNN2()

# %%
tl,ta,vl,va = train(10,train_loader1,valid_loader,cnn3,criterion,batch_size,1e-4,use_checkpoint=True,checkpoint_file='checkpoint.pth.tar')
# Out:
# Epoch [1/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4455
# Average loss of last 5 mini-batches: 0.4324
# ------------
# Accuracy on training images 84.1176
# Accuracy on test images 79.1667
# Loss on test images 0.4487
# ------------
# Epoch [2/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3962
# Average loss of last 5 mini-batches: 0.4480
# ------------
# Accuracy on training images 78.8235
# Accuracy on test images 74.1667
# Loss on test images 0.5462
# ------------
# Epoch [3/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4914
# Average loss of last 5 mini-batches: 0.4264
# ------------
# Accuracy on training images 81.4706
# Accuracy on test images 79.1667
# Loss on test images 0.4815
# ------------
# Epoch [4/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4256
# Average loss of last 5 mini-batches: 0.4180
# ------------
# Accuracy on training images 81.9118
# Accuracy on test images 78.3333
# Loss on test images 0.4656
# ------------
# Epoch [5/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3959
# Average loss of last 5 mini-batches: 0.4257
# ------------
# Accuracy on training images 83.2353
# Accuracy on test images 78.3333
# Loss on test images 0.4441
# ------------
# Epoch [6/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3903
# Average loss of last 5 mini-batches: 0.3735
# ------------
# Accuracy on training images 79.5588
# Accuracy on test images 77.5000
# Loss on test images 0.5177
# ------------
# Epoch [7/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3893
# Average loss of last 5 mini-batches: 0.4122
# ------------
# Accuracy on training images 83.5294
# Accuracy on test images 79.1667
# Loss on test images 0.4662
# ------------
# Epoch [8/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3740
# Average loss of last 5 mini-batches: 0.4222
# ------------
# Accuracy on training images 83.9706
# Accuracy on test images 80.0000
# Loss on test images 0.4403
# ------------
# Epoch [9/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.3947
# Average loss of last 5 mini-batches: 0.4250
# ------------
# Accuracy on training images 83.2353
# Accuracy on test images 77.5000
# Loss on test images 0.4674
# ------------
# Epoch [10/10]:
# -----------------
# learning rate: 0.001
# Average loss of last 5 mini-batches: 0.4267
# Average loss of last 5 mini-batches: 0.3820
# ------------
# Accuracy on training images 77.6471
# Accuracy on test images 72.5000
# Loss on test images 0.5720
# ------------
# -----------Summary--------------
# Number of iterations: 110
# Final avg loss:0.4192
# Accuracy on test images 72.5000
# Loss on test images 0.5662
# Minimum loss on test images during the entire training 0.4403
# Maximum accuracy on test images during the entire training 80.0000

# %%
checkpoint = torch.load('checkpoint.pth.tar')

# %%
#loading the state in the network and predicting on the validation
cnn3 = CNN2()
cnn3.cuda()
cnn3.load_state_dict(checkpoint['state_dict'])
predict(cnn3,valid_loader,False)
# Out:
# (81.66666666666667, 0.4301108)

# %% [markdown]
# ---

# %% [markdown]
# ### Finding optimum learning rate

# %%
def lr_finder(lr_start,lr_end,network,min_iterations):
    optimizer = torch.optim.Adam(network.parameters(), lr=lr_start) #defining your optimizer and learning rate from where you want to start
    iter_per_epoch = len(train)//batch_size
    num_epochs = math.ceil(min_iterations/iter_per_epoch)
    iter_total = num_epochs*iter_per_epoch
    
    growth_rate = (lr_end/lr_start)**(1/iter_total)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer,gamma = growth_rate,step_size=1)
    
    l = []
    lr = []
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
    #         images = Variable(images)
            images = Variable(images).cuda() #for gpu
    #         labels = Variable(labels)
            labels = Variable(labels).cuda() #for gpu

            # Forward + Backward + Optimize
            lr.append(scheduler.optimizer.param_groups[0]['lr'])
            scheduler.optimizer.zero_grad() #putting all gradients to zero
            outputs = network(images) #forward pass
            loss = criterion(outputs, labels) #calculating loss
            l.append(loss.data[0])
            loss.backward() #backward pass to calculate gradients
            scheduler.step() #updating the network parameters
    
    plt.plot(lr, l)
    return lr,l

# %%
l1,l2 = lr_finder(1e-5,1e-1,cnn,150)

# %% [markdown]
# ---
